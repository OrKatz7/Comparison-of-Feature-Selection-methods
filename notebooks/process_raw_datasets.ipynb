# %% [markdown]
# # Raw data prep

# %%
# the raw data was already processed
prepare = True

# %%
import scipy.io
import glob
import numpy as np
import pandas as pd
import os
from scipy.io import arff
from sklearn import preprocessing
from tqdm import tqdm
# import cantools

# %%
#scikit_feature_datasets
if prepare:
    for filename in glob.glob('../data/microarrays/data/scikit_feature_datasets/raw/*.mat'):
        _mat = scipy.io.loadmat(filename)
        _data = np.hstack([_mat['X'], _mat['Y']])
        _columns = [f'feature_{ii}' for ii in range(_data.shape[1])]
        _columns[-1] = 'target'
        _df = pd.DataFrame(_data, columns=_columns)
        _csv_name = filename.split(os.sep)[-1].split('.')[0]+'.csv'
        _df.to_csv(os.path.join('data/scikit_feature_datasets/', _csv_name), index=False)

# %%
# ARFF
if prepare:
    for filename in glob.glob('../data/microarrays/data/ARFF/raw/*.arff'):
        try:
            _data = arff.loadarff(filename)
            _df = pd.DataFrame(_data[0])
            _columns = list(_df.columns)
            _columns[-1] = 'target'
            _df.columns = _columns
            # _df = _df[~_df['target'].isna()]
            _df.at[_df['target'].isna(), 'target'] = 'control'
            # _df = _df.fillna(0.0)
            _csv_name = filename.split(os.sep)[-1].split('.')[0]+'.csv'
            _df.to_csv(os.path.join('data/ARFF/', _csv_name), index=False)
        except:
            pass

# %%
# bioconductor
if prepare:
    for filename in glob.glob('../data/microarrays/data/bioconductor/raw/*.csv'):
        if 'COPDSexualDimorphism' in filename: 
            continue 
        if 'DLBCL' in filename:
            continue

        _df = pd.read_csv(filename)
        _df = _df.T.reset_index(drop=True)
        _df.columns = _df.iloc[0]
        _df = _df[1:]
        _columns = list(_df.columns)
        _columns[0] = 'target'
        _df.columns = _columns 
        # _df = _df[~_df['target'].isna()]
        _df.at[_df['target'].isna(), 'target'] = 'control'
        # _df = _df.fillna(0.0)
        _csv_name = filename.split(os.sep)[-1].split('.')[0]+'.csv'
        _df.to_csv(os.path.join('data/bioconductor/', _csv_name), index=False)

# %%
# EfficientFS
if prepare:
    for filename in glob.glob('../data/microarrays/data/EfficientFS/raw/*.*'):   
        if '.csv' in filename:
            _df = pd.read_csv(filename)
            _df = _df.rename(columns = {'class':'target', ' class':'target'})
            _csv_name = filename.split(os.sep)[-1].split('.csv')[0]+'.csv'    
        elif '.mat' in filename:
            _mat = scipy.io.loadmat(filename)
            _data = np.hstack([_mat['X'], _mat['Y']])
            _columns = [f'feature_{ii}' for ii in range(_data.shape[1])]
            _columns[-1] = 'target'
            _df = pd.DataFrame(_data, columns=_columns)
            _csv_name = filename.split(os.sep)[-1].split('.mat')[0]+'.csv'    
        elif '.arff' in filename:
            try:
                _data = arff.loadarff(filename)
                _df = pd.DataFrame(_data[0])
                _columns = list(_df.columns)
                _columns[-1] = 'target'
                _df.columns = _columns  
                _csv_name = filename.split(os.sep)[-1].split('.arff')[0]+'.csv'    
            except:
                continue
        else: # not a data file
            continue
        _df.to_csv(os.path.join('data/EfficientFS/', _csv_name), index=False)

# %%
# mAML_benchmark_datasets
if prepare:
    os.makedirs('../data/microarrays/data/mAML_benchmark_datasets/LabelEncoder/', exist_ok=True)
    for filename in glob.glob('data/mAML_benchmark_datasets/raw/*/'):
        print(filename)
        csv_data = list(set(glob.glob(filename + '*.csv')) - set(glob.glob(filename + '*mf.csv')))[0]
        csv_label = glob.glob(filename + '*mf.csv')[0]
        _df_data = pd.read_csv(csv_data)
        _df_label = pd.read_csv(csv_label)
        _columns = list(_df_data.columns)
        if '#SampleID' not in _columns:
            _columns[0] = '#SampleID'
            _df_data.columns = _columns
        try:
            _df = pd.merge(_df_data, _df_label, on='#SampleID')
        except:
            continue
        _df = _df.rename(columns = {'label':'target'})
        _df = _df[list(set(_df.columns) - set(['#SampleID']))]
        le = preprocessing.LabelEncoder()
        le.fit(list(_df['target']))
        _df_LabelEncoder = pd.DataFrame([{'target_str': target_str, 'target_index':idx}  for (idx, target_str) in enumerate(list(le.classes_))])
        list(le.classes_)
        _df['target'] = le.transform(_df['target'])        
        _csv_name = csv_data.split(os.sep)[-1].split('.csv')[0]+'.csv'    
        _df_LabelEncoder.to_csv(os.path.join('data/mAML_benchmark_datasets/LabelEncoder/', _csv_name.replace('.csv', '_LabelEncoder.csv')), index=False)
        _df.to_csv(os.path.join('data/mAML_benchmark_datasets/', _csv_name), index=False)
# Out:
# data/mAML_benchmark_datasets/raw/Cho2012_Antibiotics_cecal.5/
# data/mAML_benchmark_datasets/raw/Cho2012_Antibiotics_fecal.5/
# data/mAML_benchmark_datasets/raw/Costello2009_BodyHabitats.6/
# data/mAML_benchmark_datasets/raw/Costello2009_SkinSites.12/
# data/mAML_benchmark_datasets/raw/Costello2009_Subject.7/
# data/mAML_benchmark_datasets/raw/Fierer2010_Subject.3/
# data/mAML_benchmark_datasets/raw/Fierer2010_SubjectH.6/
# data/mAML_benchmark_datasets/raw/Gevers2014_IBD_ileum/
# data/mAML_benchmark_datasets/raw/Gevers2014_IBD_rectum/
# data/mAML_benchmark_datasets/raw/Huttenhower2012_HMP.BS.5/
# data/mAML_benchmark_datasets/raw/Karlsson2013_Diabetes.3/
# data/mAML_benchmark_datasets/raw/Montassier2016_Bacteremia/
# data/mAML_benchmark_datasets/raw/Morgan2012_IBD.3/
# data/mAML_benchmark_datasets/raw/Qin2012_Diabetes/
# data/mAML_benchmark_datasets/raw/Qin2014_Cirrhosis/
# data/mAML_benchmark_datasets/raw/Ravel2011_Vaginal/
# data/mAML_benchmark_datasets/raw/Wu2011_Diet/
# data/mAML_benchmark_datasets/raw/Yang2010_EsophagitisPDX.4/

# %% [markdown]
# # How to load

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score
# from tqdm import tqdm
summary_data = []

for idx, csv in tqdm(enumerate(glob.glob('data/*/*.csv'))):
    # print(csv)
    df = pd.read_csv(csv)
#     train_df, test_df = train_test_split(df, test_size=0.2, stratify=df['target'])
    
#     y_train = train_df.pop('target')
#     y_train = y_train.to_numpy()
#     X_train = train_df.to_numpy()

#     y_test = test_df.pop('target')
#     y_test = y_test.to_numpy()
#     X_test = test_df.to_numpy()
    
#     clf = RandomForestClassifier(random_state=42)
#     clf.fit(X_train, y_train)
#     y_pred = clf.predict(X_test)
#     acc = accuracy_score(y_test, y_pred)
    
    features_count = df.shape[1]
    samples_count = df.shape[0]
    # num_classes = len(set(y_test))
    num_classes = len(set(df['target']))
    
    
    summary_data.append({
        'path':csv,
        'name':csv.split(os.sep)[-1],
        'corpus':csv.split(os.sep)[-2],
        'samples': samples_count,
        'features': features_count,        
        'num_classes': num_classes,
        'has_na': True if df.isnull().values.any() else False,
        'na_target_to_control': True if 'control' in list(df['target']) else False,
        # 'baseline_acc': acc,
    })
    
summary_df = pd.DataFrame(summary_data)
# Out:
# 70it [00:53,  1.31it/s]

# %%
pd.set_option('display.max_rows', None)
display(summary_df)
pd.set_option('display.max_rows', 10)
# Out:
#                                                  path  \
# 0                                data/ARFF/Breast.csv
# 1                                   data/ARFF/CNS.csv
# 2                           data/ARFF/Leukemia_3c.csv
# 3                           data/ARFF/Leukemia_4c.csv
# 4                                  data/ARFF/Lung.csv
# 5                              data/ARFF/Lymphoma.csv
# 6                                   data/ARFF/MLL.csv
# 7                               data/ARFF/Ovarian.csv
# 8                                 data/ARFF/SRBCT.csv
# 9                           data/bioconductor/ALL.csv
# 10                     data/bioconductor/ayeastCC.csv
# 11                   data/bioconductor/bcellViper.csv
# 12                 data/bioconductor/bladderbatch.csv
# 13              data/bioconductor/breastCancerVDX.csv
# 14                          data/bioconductor/CLL.csv
# 15           data/bioconductor/curatedOvarianData.csv
# 16                data/bioconductor/leukemiasEset.csv
# 17            data/scikit_feature_datasets/ALLAML.csv
# 18            data/scikit_feature_datasets/arcene.csv
# 19          data/scikit_feature_datasets/BASEHOCK.csv
# 20          data/scikit_feature_datasets/Carcinom.csv
# 21       data/scikit_feature_datasets/CLL-SUB-111.csv
# 22            data/scikit_feature_datasets/COIL20.csv
# 23             data/scikit_feature_datasets/colon.csv
# 24           data/scikit_feature_datasets/gisette.csv
# 25            data/scikit_feature_datasets/GLI-85.csv
# 26            data/scikit_feature_datasets/GLIOMA.csv
# 27            data/scikit_feature_datasets/Isolet.csv
# 28          data/scikit_feature_datasets/leukemia.csv
# 29              data/scikit_feature_datasets/lung.csv
# 30        data/scikit_feature_datasets/lung_small.csv
# 31          data/scikit_feature_datasets/lymphoma.csv
# 32           data/scikit_feature_datasets/madelon.csv
# 33              data/scikit_feature_datasets/nci9.csv
# 34               data/scikit_feature_datasets/ORL.csv
# 35        data/scikit_feature_datasets/orlraws10P.csv
# 36             data/scikit_feature_datasets/PCMAC.csv
# 37         data/scikit_feature_datasets/pixraw10P.csv
# 38       data/scikit_feature_datasets/Prostate-GE.csv
# 39           data/scikit_feature_datasets/RELATHE.csv
# 40       data/scikit_feature_datasets/SMK-CAN-187.csv
# 41           data/scikit_feature_datasets/TOX-171.csv
# 42              data/scikit_feature_datasets/USPS.csv
# 43         data/scikit_feature_datasets/warpAR10P.csv
# 44        data/scikit_feature_datasets/warpPIE10P.csv
# 45              data/scikit_feature_datasets/Yale.csv
# 46  data/mAML_benchmark_datasets/Cho2012_Antibioti...
# 47  data/mAML_benchmark_datasets/Cho2012_Antibioti...
# 48  data/mAML_benchmark_datasets/Costello2009_Body...
# 49  data/mAML_benchmark_datasets/Costello2009_Skin...
# 50  data/mAML_benchmark_datasets/Costello2009_Subj...
# 51  data/mAML_benchmark_datasets/Fierer2010_Subjec...
# 52  data/mAML_benchmark_datasets/Fierer2010_Subjec...
# 53  data/mAML_benchmark_datasets/Gevers2014_IBD_il...
# 54  data/mAML_benchmark_datasets/Gevers2014_IBD_re...
# 55  data/mAML_benchmark_datasets/Huttenhower2012_H...
# 56  data/mAML_benchmark_datasets/Karlsson2013_Diab...
# 57  data/mAML_benchmark_datasets/Montassier2016_Ba...
# 58  data/mAML_benchmark_datasets/Morgan2012_IBD.3.csv
# 59  data/mAML_benchmark_datasets/Qin2012_Diabetes.csv
# 60  data/mAML_benchmark_datasets/Qin2014_Cirrhosis...
# 61  data/mAML_benchmark_datasets/Ravel2011_Vaginal...
# 62       data/mAML_benchmark_datasets/Wu2011_Diet.csv
# 63  data/mAML_benchmark_datasets/Yang2010_Esophagi...
# 64             data/EfficientFS/pone.0202167.s011.csv
# 65             data/EfficientFS/pone.0202167.s012.csv
# 66             data/EfficientFS/pone.0202167.s013.csv
# 67             data/EfficientFS/pone.0202167.s015.csv
# 68             data/EfficientFS/pone.0202167.s016.csv
# 69             data/EfficientFS/pone.0202167.s017.csv
#
#                                name                   corpus  samples  \
# 0                        Breast.csv                     ARFF       97
# 1                           CNS.csv                     ARFF       60
# 2                   Leukemia_3c.csv                     ARFF       72
# 3                   Leukemia_4c.csv                     ARFF       72
# 4                          Lung.csv                     ARFF      203
# 5                      Lymphoma.csv                     ARFF       66
# 6                           MLL.csv                     ARFF       72
# 7                       Ovarian.csv                     ARFF      253
# 8                         SRBCT.csv                     ARFF       83
# 9                           ALL.csv             bioconductor      128
# 10                     ayeastCC.csv             bioconductor       50
# 11                   bcellViper.csv             bioconductor      211
# 12                 bladderbatch.csv             bioconductor       57
# 13              breastCancerVDX.csv             bioconductor      344
# 14                          CLL.csv             bioconductor       22
# 15           curatedOvarianData.csv             bioconductor      194
# 16                leukemiasEset.csv             bioconductor       60
# 17                       ALLAML.csv  scikit_feature_datasets       72
# 18                       arcene.csv  scikit_feature_datasets      200
# 19                     BASEHOCK.csv  scikit_feature_datasets     1993
# 20                     Carcinom.csv  scikit_feature_datasets      174
# 21                  CLL-SUB-111.csv  scikit_feature_datasets      111
# 22                       COIL20.csv  scikit_feature_datasets     1440
# 23                        colon.csv  scikit_feature_datasets       62
# 24                      gisette.csv  scikit_feature_datasets     7000
# 25                       GLI-85.csv  scikit_feature_datasets       85
# 26                       GLIOMA.csv  scikit_feature_datasets       50
# 27                       Isolet.csv  scikit_feature_datasets     1560
# 28                     leukemia.csv  scikit_feature_datasets       72
# 29                         lung.csv  scikit_feature_datasets      203
# 30                   lung_small.csv  scikit_feature_datasets       73
# 31                     lymphoma.csv  scikit_feature_datasets       96
# 32                      madelon.csv  scikit_feature_datasets     2600
# 33                         nci9.csv  scikit_feature_datasets       60
# 34                          ORL.csv  scikit_feature_datasets      400
# 35                   orlraws10P.csv  scikit_feature_datasets      100
# 36                        PCMAC.csv  scikit_feature_datasets     1943
# 37                    pixraw10P.csv  scikit_feature_datasets      100
# 38                  Prostate-GE.csv  scikit_feature_datasets      102
# 39                      RELATHE.csv  scikit_feature_datasets     1427
# 40                  SMK-CAN-187.csv  scikit_feature_datasets      187
# 41                      TOX-171.csv  scikit_feature_datasets      171
# 42                         USPS.csv  scikit_feature_datasets     9298
# 43                    warpAR10P.csv  scikit_feature_datasets      130
# 44                   warpPIE10P.csv  scikit_feature_datasets      210
# 45                         Yale.csv  scikit_feature_datasets      165
# 46  Cho2012_Antibiotics_cecal.5.csv  mAML_benchmark_datasets       47
# 47  Cho2012_Antibiotics_fecal.5.csv  mAML_benchmark_datasets       45
# 48  Costello2009_BodyHabitats.6.csv  mAML_benchmark_datasets      552
# 49    Costello2009_SkinSites.12.csv  mAML_benchmark_datasets      357
# 50       Costello2009_Subject.7.csv  mAML_benchmark_datasets      140
# 51         Fierer2010_Subject.3.csv  mAML_benchmark_datasets      104
# 52        Fierer2010_SubjectH.6.csv  mAML_benchmark_datasets       98
# 53         Gevers2014_IBD_ileum.csv  mAML_benchmark_datasets      140
# 54        Gevers2014_IBD_rectum.csv  mAML_benchmark_datasets      160
# 55     Huttenhower2012_HMP.BS.5.csv  mAML_benchmark_datasets     1529
# 56      Karlsson2013_Diabetes.3.csv  mAML_benchmark_datasets      144
# 57    Montassier2016_Bacteremia.csv  mAML_benchmark_datasets       28
# 58             Morgan2012_IBD.3.csv  mAML_benchmark_datasets      128
# 59             Qin2012_Diabetes.csv  mAML_benchmark_datasets      124
# 60            Qin2014_Cirrhosis.csv  mAML_benchmark_datasets      130
# 61            Ravel2011_Vaginal.csv  mAML_benchmark_datasets      342
# 62                  Wu2011_Diet.csv  mAML_benchmark_datasets       85
# 63    Yang2010_EsophagitisPDX.4.csv  mAML_benchmark_datasets      200
# 64            pone.0202167.s011.csv              EfficientFS       97
# 65            pone.0202167.s012.csv              EfficientFS       60
# 66            pone.0202167.s013.csv              EfficientFS       62
# 67            pone.0202167.s015.csv              EfficientFS      253
# 68            pone.0202167.s016.csv              EfficientFS       34
# 69            pone.0202167.s017.csv              EfficientFS      102
#
#     features  num_classes  has_na  na_target_to_control
# 0      24482            2   False                 False
# 1       7130            2   False                 False
# 2       7130            3   False                 False
# 3       7130            4   False                 False
# 4      12601            5   False                 False
# 5       4027            3    True                 False
# 6      12583            3   False                 False
# 7      15155            2   False                 False
# 8       2309            4   False                 False
# 9      12626            3   False                  True
# 10      6229            2    True                 False
# 11      6250           21   False                 False
# 12     22284            3   False                 False
# 13     22285            2    True                 False
# 14     12626            2   False                 False
# 15      3585            3    True                  True
# 16     20173            5   False                 False
# 17      7130            2   False                 False
# 18     10001            2   False                 False
# 19      4863            2   False                 False
# 20      9183           11   False                 False
# 21     11341            3   False                 False
# 22      1025           20   False                 False
# 23      2001            2   False                 False
# 24      5001            2   False                 False
# 25     22284            2   False                 False
# 26      4435            4   False                 False
# 27       618           26   False                 False
# 28      7071            2   False                 False
# 29      3313            5   False                 False
# 30       326            7   False                 False
# 31      4027            9   False                 False
# 32       501            2   False                 False
# 33      9713            9   False                 False
# 34      1025           40   False                 False
# 35     10305           10   False                 False
# 36      3290            2   False                 False
# 37     10001           10   False                 False
# 38      5967            2   False                 False
# 39      4323            2   False                 False
# 40     19994            2   False                 False
# 41      5749            4   False                 False
# 42       257           10   False                 False
# 43      2401           10   False                 False
# 44      2421           10   False                 False
# 45      1025           15   False                 False
# 46       122            5   False                 False
# 47       108            5   False                 False
# 48      6980            6   False                 False
# 49      4794           12   False                 False
# 50      2544            7   False                 False
# 51      1218            3   False                 False
# 52      1218            6   False                 False
# 53       100            2   False                 False
# 54       109            2   False                 False
# 55       324            5   False                 False
# 56      1461            3   False                 False
# 57       392            2   False                 False
# 58       688            3   False                 False
# 59     11881            2   False                 False
# 60      8484            2   False                 False
# 61       510            2   False                 False
# 62       286            2   False                 False
# 63     74019            4   False                 False
# 64     24482            2   False                 False
# 65      7130            2   False                 False
# 66      2001            2   False                 False
# 67     15155            2   False                 False
# 68     12601            2   False                 False
# 69     12601            2   False                 False

# %%
# summary_df.to_csv('../../data/microarrays/data_summary.csv', index=False)

# %%
# toy example
if prepare:
    filename = '../data/microarrays/data_toy_example/SPECTF.train'
    _df = pd.read_csv(filename, header=None)
    _columns = [f'feature_{ii-1}' for ii in range(_df.shape[1])]
    _columns[0] = 'target'
    _df.columns = _columns 
    display(_df.head(3))
    _df.to_csv('../data/microarrays/data_toy_example/SPECTF_train.csv', index=False)
# Out:
#    target  feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0       1         59         52         70         67         73         66
# 1       1         72         62         69         67         78         82
# 2       1         71         62         70         64         67         64
#
#    feature_6  feature_7  feature_8  ...  feature_34  feature_35  feature_36  \
# 0         72         61         58  ...          66          56          62
# 1         74         65         69  ...          65          71          63
# 2         79         65         70  ...          73          70          66
#
#    feature_37  feature_38  feature_39  feature_40  feature_41  feature_42  \
# 0          56          72          62          74          74          64
# 1          60          69          73          67          71          56
# 2          65          64          55          61          41          51
#
#    feature_43
# 0          67
# 1          58
# 2          46
#
# [3 rows x 45 columns]

# %%
set(_df['target'])
# Out:
# {0, 1}

# %%
_csv_name
# Out:
# 'SPECTF.csv'
